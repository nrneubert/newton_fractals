# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
import os

repo_root = os.path.abspath('..')              
classes_path = os.path.join(repo_root, 'fractal_backend', 'fractal_backend', 'classes')
sys.path.append(classes_path)

from Newton_Fractal import NewtonFractal

# %%
roots = np.array([
    1,
    np.exp(2j * np.pi / 3),
    np.exp(4j * np.pi / 3),
])

amps = np.zeros(shape=9)
amps[0] = -16.0
amps[5] = +15.0
amps[-1] = 1.0

computer = NewtonFractal(coeffs=amps)
rlim = (-1.0, 1.0)
ilim = (-1.0, 1.0)
rgbs = computer.generate_fractal(real_lim=rlim, imag_lim=ilim, pixels=1000, cores=16)
# Out:
# Computing grid...:   3%|▎         | 34319/1000000 [00:02<00:55, 17390.26it/s]Process ForkPoolWorker-7:
# Process ForkPoolWorker-9:
# Computing grid...:   4%|▎         | 35678/1000000 [00:02<01:06, 14579.25it/s]Process ForkPoolWorker-3:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-5:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ...

# %%
fig, ax = plt.subplots(figsize=(9,9))

ax.imshow(rgbs)
ax.axis('off')
#fig.subplots_adjust(left=0, right=1, top=1, bottom=0)

#computer.save_fig(fig, file_format='png', dpi=1500)
# Out:
# (np.float64(-0.5), np.float64(999.5), np.float64(999.5), np.float64(-0.5))

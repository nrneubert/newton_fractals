# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
import os

repo_root = os.path.abspath('..')              
classes_path = os.path.join(repo_root, 'backend', 'api', 'fractals')
sys.path.append(classes_path)

from Newton_Fractal import NewtonFractal

# %%
roots = np.array([
    1,
    np.exp(2j * np.pi / 3),
    np.exp(4j * np.pi / 3),
])

amps = np.zeros(shape=9, dtype=complex)
amps[0] = -16.0
amps[5] = +15.0
amps[-1] = 1.0

computer = NewtonFractal(coeffs=amps)
rlim = (-1.0, 1.0)
ilim = (-1.0, 1.0)
rgbs = computer.generate_fractal(real_lim=rlim, imag_lim=ilim, pixels=200, cores=16)
# Out:
# Computing grid...: 100%|██████████| 40000/40000 [00:05<00:00, 7510.34it/s]

# %%
fig, ax = plt.subplots(figsize=(9,9))

ax.imshow(rgbs)
ax.axis('off')
#fig.subplots_adjust(left=0, right=1, top=1, bottom=0)

#computer.save_fig(fig, file_format='png', dpi=1500)
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(199.5), np.float64(-0.5))
